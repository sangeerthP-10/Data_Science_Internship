# %% [markdown]
# <a href="https://colab.research.google.com/github/sangeerthP-10/Data_Science_Internship/blob/main/Data_science_internship_(day_9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Functions

# %%
def function():
  print("Python")
function()
# Out:
# Python

# %%
def Greeting(name):
  print(" Hello, "+name)
Greeting("Sangeerth")
# Out:
#  Hello, Sangeerth

# %%
def add(a,b):
  result=a+b
  print(result)
add(5,6)
add(2,10)
# Out:
# 11
# 12

# %%
def Greeting(name ,seat_number):
  print("Hello, "+name+ "\nYour seat number is : "+seat_number )
Greeting("Sangeerth","68789")
print("Please take your seat")
print(" ")
Greeting("John","58723")
# Out:
# Hello, Sangeerth
# Your seat number is : 68789
# Please take your seat
#
# Hello, John
# Your seat number is : 58723

# %%
def Greeting(name ,seat_number="00001"):
  print("Hello, "+name+ "\nYour seat number is : "+seat_number )
Greeting("Sangeerth","68789")
print("Please take your seat")
print(" ")
Greeting("John","58723")
Greeting("Don")
# Out:
# Hello, Sangeerth
# Your seat number is : 68789
# Please take your seat
#
# Hello, John
# Your seat number is : 58723
# Hello, Don
# Your seat number is : 00001

# %%
def square(x):
  print(x*x)
square(5)
# Out:
# 25

# %%
def square(x):
  return(x*x)
square(5)
# Out:
# 25
