# %% [markdown]
# <a href="https://colab.research.google.com/github/sangeerthP-10/Data_Science_Internship/blob/main/Data_science_internship_(day_8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# List

# %%
fruits=["apple","mango","banana","orange"]

# %%
fruits
# Out:
# ['apple', 'mango', 'banana', 'orange']

# %%
fruits[2]="grapes"

# %%
fruits
# Out:
# ['apple', 'mango', 'grapes', 'orange']

# %%
if "apple" in fruits:
  print("apple is present")
# Out:
# apple is present

# %%
fruits.append("banana")

# %%
fruits
# Out:
# ['apple', 'mango', 'grapes', 'orange', 'banana']

# %%
fruits.insert(2,"pineapple")

# %%
fruits
# Out:
# ['apple', 'mango', 'pineapple', 'grapes', 'orange', 'banana']

# %%
fruits.pop()
# Out:
# 'banana'

# %%
fruits.remove("mango")

# %%
fruits
# Out:
# ['apple', 'pineapple', 'grapes', 'orange']

# %%
a=fruits
print(a)
b=fruits.copy()
print(b)

b.pop()

print(a,b)
# Out:
# ['apple', 'pineapple', 'grapes', 'orange']
# ['apple', 'pineapple', 'grapes', 'orange']
# ['apple', 'pineapple', 'grapes', 'orange'] ['apple', 'pineapple', 'grapes']

# %% [markdown]
# Tuple

# %%
veg=("carrot","raddish","onion","tomato","cucumber")
veg
# Out:
# ('carrot', 'raddish', 'onion', 'tomato', 'cucumber')

# %%
dir(veg)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
aa=("chilly",200)

# %%
veg2=veg+aa
print(veg2)
# Out:
# ('carrot', 'raddish', 'onion', 'tomato', 'cucumber', 'chilly', 200)

# %% [markdown]
# Sets

# %%
vege={"carrot","raddish","onion","tomato","cucumber","cucumber"}
vege
# Out:
# {'carrot', 'cucumber', 'onion', 'raddish', 'tomato'}

# %%
vege.add("chilly")
vege
# Out:
# {'carrot', 'chilly', 'cucumber', 'onion', 'raddish', 'tomato'}

# %%
vege.add("beans")
vege
# Out:
# {'beans', 'carrot', 'chilly', 'cucumber', 'onion', 'raddish', 'tomato'}

# %%
vege.update({"ladyfinger","kappa"})
vege
# Out:
# {'beans',
#  'carrot',
#  'chilly',
#  'cucumber',
#  'kappa',
#  'ladyfinger',
#  'onion',
#  'raddish',
#  'tomato'}

# %%
vege.remove("kappa")
vege
# Out:
# {'beans',
#  'carrot',
#  'chilly',
#  'cucumber',
#  'ladyfinger',
#  'onion',
#  'raddish',
#  'tomato'}

# %%
vege.discard("ladyfinger")

# %%
vege
# Out:
# {'beans', 'carrot', 'chilly', 'cucumber', 'onion', 'raddish', 'tomato'}

# %%
print(vege)
vege.pop()
print(vege)
vege.pop()
print(vege)
# Out:
# {'chilly', 'beans', 'tomato', 'cucumber', 'raddish', 'onion'}
# {'beans', 'tomato', 'cucumber', 'raddish', 'onion'}
# {'tomato', 'cucumber', 'raddish', 'onion'}

# %% [markdown]
# Dictionaries

# %%
person={
    "name":"Sangeerth",
    "age":22,
    "gender":"Male"

}
person
# Out:
# {'name': 'Sangeerth', 'age': 22, 'gender': 'Male'}

# %%
age=person["age"]
age
# Out:
# 22
