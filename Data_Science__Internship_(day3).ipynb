# %% [markdown]
# <a href="https://colab.research.google.com/github/sangeerthP-10/Prinston-Smart-Engineers-Internship/blob/main/Data_Science__Internship_(day3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=5
print(x)
# Out:
# 5

# %%
x=10
y=20
z=x+y
z
# Out:
# 30

# %%
a=x*y
b=x-y
c=x/y
d=x%y
e=y//x
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# 200
# -10
# 0.5
# 10
# 2

# %% [markdown]
# BOOL

# %%
2==3
# Out:
# False

# %%
2!=5
# Out:
# True

# %%
a=3
b=5

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a=b

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("hello", "  ","5")
# Out:
# hello    5
