# %% [markdown]
# <a href="https://colab.research.google.com/github/sangeerthP-10/Data_Science_Internship/blob/main/Data_Science_Internship(day5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# String Indexing

# %%
s="Welcome to Bengaluru"

# %%
print(s[:])
# Out:
# Welcome to Bengaluru

# %%
print(s[:5])
# Out:
# Welco

# %%
print(s[3:])
# Out:
# come to Bengaluru

# %%
algotithm="Neural Network"

# %%
len(algotithm)
# Out:
# 14

# %%
print(algotithm)
# Out:
# Neural Network

# %%
algotithm.lower()
# Out:
# 'neural network'

# %%
a=algotithm.lower()

# %%
a
# Out:
# 'neural network'

# %%
algotithm.upper()
# Out:
# 'NEURAL NETWORK'

# %%
algotithm
# Out:
# 'Neural Network'

# %%
print(algotithm.count('Ne'))
print(algotithm.count('Neural'))
print(algotithm.count(' '))
print(algotithm.count('N'))
print(algotithm.count('e'))
print(algotithm.count('Nerela'))
# Out:
# 2
# 1
# 1
# 2
# 2
# 0

# %% [markdown]
# Replace()

# %%
algotithm
# Out:
# 'Neural Network'

# %%
algotithm.replace(' ','-')
# Out:
# 'Neural-Network'

# %%
algotithm
# Out:
# 'Neural Network'

# %%
algotithm.replace(' ','_')
# Out:
# 'Neural_Network'

# %% [markdown]
# Strip

# %%
z="    How are you             "

# %%
z
# Out:
# '    How are you             '

# %%
z.strip()
# Out:
# 'How are you'

# %%
z
# Out:
# '    How are you             '

# %%
print(z)
a=z=z.strip()
print(a)
print(z)
# Out:
#     How are you
# How are you
# How are you

# %% [markdown]
# Split()

# %%
a="Madhya Pradesh"

# %%
print(a.split(' '))
print(a.split('a'))
print(a.split('y'))
print(a.split('r'))
print(a.split('d'))
# Out:
# ['Madhya', 'Pradesh']
# ['M', 'dhy', ' Pr', 'desh']
# ['Madh', 'a Pradesh']
# ['Madhya P', 'adesh']
# ['Ma', 'hya Pra', 'esh']

# %%
a="hi"
b="Akash"
print(a+" "+b)
# Out:
# hi Akash

# %% [markdown]
# Conditional Sataments

# %% [markdown]
# If

# %%
x=7
if x<5:
  print("x is less than 5")
else:
  print("x is greater than 5")
# Out:
# x is greater than 5

# %%
a=5
b=5
if a==b:
  print("a is eaqual to b")
else:
  print("Not Equal")
# Out:
# a is eaqual to b
