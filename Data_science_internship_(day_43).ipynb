# %% [markdown]
# <a href="https://colab.research.google.com/github/sangeerthP-10/Data_Science_Internship/blob/main/Data_science_internship_(day_43).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
43!pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# #Load model

# %%
from ultralytics import YOLO
model =YOLO('yolov8n.pt')

# %%
result=model('burger.jpg')
import matplotlib.pyplot as plt
img=result[0].plot()
plt .figure(figsize=(10,6))
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/burger.jpg: 448x640 8 persons, 3 handbags, 81.7ms
# Speed: 12.4ms preprocess, 81.7ms inference, 47.3ms postprocess per image at shape (1, 3, 448, 640)
